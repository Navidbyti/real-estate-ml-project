# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("../../../Divar.csv")
# Out:
# C:\Users\Rumi\AppData\Local\Temp\ipykernel_25632\2225313960.py:6: DtypeWarning: Columns (11,27,29,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../../Divar.csv")

# %% [markdown]
# <div  dir="rtl" align="right">
#
# 4.در دسته‌بندی امکانات موجود در آگهی‌ها می‌توانیم آنها را به دو دسته‌ی امکانات لاکچری(استخر، باربیکیو، سونا، جکوزی) و امکانات غیر لاکچری تقسیم کنیم. فرضیه‌ی ما این است که میانگین مبلغ قیمت برای وجود ویژگی‌های لاکچری افزایش چشم‌گیری دارد. اما آیا این میانگین برای وجود امکانات غیرلاکچری نیز تفاوت معناداری دارد؟

# %% [markdown]
# <div  dir="rtl" align="right">
#
#
# ### جدا کردن فضا های فرضیه:
#
#
# #### امکانات لاکچری
# فرضیه صفر (H₀)
#
# میانگین قیمت آگهی‌هایی که حداقل یکی از امکانات لاکچری (استخر، سونا، جکوزی یا باربیکیو) را دارند،
# با میانگین قیمت آگهی‌هایی که هیچ‌کدام از این امکانات را ندارند تفاوت معناداری ندارد.
#
# فرضیه مقابل (H₁)
#
# میانگین قیمت آگهی‌هایی که حداقل یکی از امکانات لاکچری (استخر، سونا، جکوزی یا باربیکیو) را دارند،
# به‌طور معناداری بیشتر از میانگین قیمت آگهی‌هایی است که فاقد این امکانات هستند.
#
#
# #### امکانات غیرلاکچری
#
# فرضیه صفر (H₀)
#
# میانگین قیمت آگهی‌هایی که دارای امکانات غیرلاکچری هستند،
# با میانگین قیمت آگهی‌هایی که فاقد این امکانات‌اند تفاوت معناداری ندارد.
#
# فرضیه مقابل (H₁)
#
# میانگین قیمت آگهی‌هایی که دارای امکانات غیرلاکچری هستند،
# با میانگین قیمت آگهی‌هایی که فاقد این امکانات‌اند تفاوت معناداری دارد.

# %%
luxury_columns = [
    'has_pool',
    'has_jacuzzi',
    'has_sauna', 
    'has_barbecue']

df4 = df.copy()
df4 = df4[df4["price_value"] > 10000000] #Zir 1 million toman melk be forush nemiresad
df4 = df4[df4["price_value"] < 1e+13] # Va balae 1 trilion toman ham nist
df4 = df4[~df4["price_value"].isna()]
df4["has_luxury"] = df4[luxury_columns].any(axis=1)
df_luxury = df4[df4["has_luxury"]]
df_not_luxury = df4[~df4["has_luxury"]]

non_luxury_columns = [
    'has_elevator',
    'has_parking',
    'has_warehouse',
    'has_balcony',
    'has_heating_system',
    'has_cooling_system',
    'has_security_guard',
    'has_water',
    'has_gas',
    'has_electricity',
    'has_restroom'
]

df4["has_non_luxury"] = df4[non_luxury_columns].any(axis= 1)

df_non_luxury = df4[df4["has_non_luxury"]]
df_not_non_luxury = df4[~df4["has_non_luxury"]]

# %%
fig, axes = plt.subplots(nrows=1, ncols=4,figsize=(20, 5))

dfs = [df_luxury, df_not_luxury ,df_non_luxury , df_not_non_luxury]
lables = ["df_luxury", "df_not_luxury" ,"df_non_luxury" , "df_not_non_luxury"]
for i , dfx in enumerate(dfs):
    axes[i].hist(np.log10(dfx["price_value"]), bins=50)
    axes[i].set_xlabel(lables[i])


plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(np.log10(dfs[0]["price_value"].dropna()), bins=50, alpha=0.5, color='blue', label=lables[0])
plt.hist(np.log10(dfs[1]["price_value"].dropna().sample(dfs[0].shape[0], random_state=42)), bins=50, alpha=0.5, color='red', label=lables[1])
plt.xlabel("Log10 Price")
plt.ylabel("Density")
plt.title("Price Distribution: Group 0 vs Group 1")
plt.legend()
plt.show()

plt.figure(figsize=(10,6))
plt.hist(np.log10(dfs[2]["price_value"].dropna().sample(dfs[3].shape[0])), bins=50, alpha=0.5, color='green', label=lables[2])
plt.hist(np.log10(dfs[3]["price_value"].dropna()), bins=50, alpha=0.5, color='orange', label=lables[3])
plt.xlabel("Log10 Price")
plt.ylabel("Density")
plt.title("Price Distribution: Group 2 vs Group 3")
plt.legend()
plt.show()

# %%
from scipy.stats import shapiro

for i , dfx in enumerate(dfs):
    test = 0
    for j in range(10):
        shapiro_test = shapiro(np.log10(dfx["price_value"].sample(1000, random_state=j)))
        if shapiro_test.pvalue > 0.05:
            test += 1
    if test > 5:
        print(lables[i], " is Normal :", test)
    else:
        print(lables[i], " is NOT Normal :" , test)
# Out:
# df_luxury  is NOT Normal : 0
# df_not_luxury  is NOT Normal : 0
# df_non_luxury  is NOT Normal : 0
# df_not_non_luxury  is NOT Normal : 0

# %%
from scipy.stats import mannwhitneyu

stat, p_value = mannwhitneyu(np.log10(df_luxury["price_value"]) , np.log10(df_not_luxury["price_value"]))

if p_value < 0.05:
    print('Reject Null Hypothesis (Significant difference between two samples) p =', p_value)
else:
    print('Do not Reject Null Hypothesis (No significant difference between two samples) p =' ,p_value)
# Out:
# Reject Null Hypothesis (Significant difference between two samples) p = 9.467889814781265e-08

# %%
from scipy.stats import mannwhitneyu

stat, p_value = mannwhitneyu(np.log10(df_luxury["price_value"].sample(min(df_luxury.shape[0], df_not_luxury.shape[0]), random_state=42)) , np.log10(df_not_luxury["price_value"].sample(min(df_luxury.shape[0], df_not_luxury.shape[0]), random_state=42)))

if p_value < 0.05:
    print('Reject Null Hypothesis (Significant difference between two samples) p =', p_value)
else:
    print('Do not Reject Null Hypothesis (No significant difference between two samples) p =' ,p_value)
# Out:
# Reject Null Hypothesis (Significant difference between two samples) p = 0.015969539366443797

# %% [markdown]
# <div dir="rtl">
#
# **گروه 0 vs 1:** آزمون Mann-Whitney نشان‌دهنده تفاوت آماری است (p = 0.016).
#
# </div>

# %%
group1 = np.log10(df_luxury["price_value"].dropna().sample(min(df_luxury.shape[0], df_not_luxury.shape[0]), random_state=42))
group2 = np.log10(df_not_luxury["price_value"].dropna().sample(min(df_luxury.shape[0], df_not_luxury.shape[0]), random_state=42))

u_stat, p_value = mannwhitneyu(group1, group2, alternative='two-sided', method='asymptotic')

# Compute effect size
n1 = len(group1)
n2 = len(group2)
N = n1 + n2

# Mean and std of U under null
mu_U = n1 * n2 / 2
sigma_U = np.sqrt(n1 * n2 * (n1 + n2 + 1) / 12)

# Z-score
z = (u_stat - mu_U) / sigma_U

# Effect size
r = z / np.sqrt(N)

print(f"Mann-Whitney p-value: {p_value}")
print(f"Effect size r: {r:.4f}")
# Out:
# Mann-Whitney p-value: 0.015969539366443797
# Effect size r: 0.0217

# %% [markdown]
# <div dir="rtl">
#
# **گروه 0 vs 1:** اندازه اثر بسیار کوچک است (r = 0.022)، تفاوت عملی قابل توجهی ندارد.
#
# </div>

# %%
group3 = np.log10(df_non_luxury["price_value"].sample(min(df_non_luxury.shape[0], df_not_non_luxury.shape[0]), random_state=42))
group4 = np.log10(df_not_non_luxury["price_value"].sample(min(df_non_luxury.shape[0], df_not_non_luxury.shape[0]), random_state=42))

stat, p_value = mannwhitneyu(group3 , group4)

# Compute effect size
n1 = len(group3)
n2 = len(group4)
N = n1 + n2

# Mean and std of U under null
mu_U = n1 * n2 / 2
sigma_U = np.sqrt(n1 * n2 * (n1 + n2 + 1) / 12)

# Z-score
z = (stat - mu_U) / sigma_U

# Effect size
r = z / np.sqrt(N)



if p_value < 0.05:
    print('Reject Null Hypothesis (Significant difference between two samples) p =', p_value)
else:
    print('Do not Reject Null Hypothesis (No significant difference between two samples) p =' ,p_value)

print(f"Effect size r: {r:.4f}")
# Out:
# Reject Null Hypothesis (Significant difference between two samples) p = 0.0
# Effect size r: 0.2774

# %% [markdown]
# <div dir="rtl">
#
# **گروه 2 vs 3:** اندازه اثر متوسط است (r = 0.277)، تفاوت عملی قابل توجه است.
#
# </div>

# %% [markdown]
# <div  dir="rtl" align="right">
#
#
# «نتایج آزمون Mann–Whitney U نشان داد که هم وجود امکانات لاکچری و هم وجود امکانات غیرلاکچری منجر به تفاوت معنادار در قیمت آگهی‌ها می‌شود (p-value < 0.05). با این حال، اثر امکانات لاکچری از نظر شدت و تفاوت قیمتی قوی‌تر و چشم‌گیرتر است.»

# %% [markdown]
# آزمون فرض شماره 1:با توجه به رشد مهاجرت افراد از شهر‌های کوچکتر به کلان‌شهر‌ها و تراکم جمعیت در این نواحی، تصور می‌شود که میانگین مساحت خانه‌های مسکونی در کلان‌شهرها نسبت به شهر‌های کوچک و روستاها کمتر است. آیا مجموعه داده‌ این فرضیه را پشتیبانی می‌کند؟(برای دسته‌بندی شهرها به کلان‌شهر و شهر کوچک می‌توانید از این مجموعه داده استفاده کنید.)

# %%
import pandas as pd


df_divar = pd.read_csv("C:/Users/Memari/Downloads/Divar.csv")
df_city = pd.read_csv("C:/Users/Memari/Downloads/iran_city_classification.csv")
# Out:
# C:\Users\Memari\AppData\Local\Temp\ipykernel_15124\72968499.py:4: DtypeWarning: Columns (11,27,29,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_divar = pd.read_csv("C:/Users/Memari/Downloads/Divar.csv")

# %%
import pandas as pd

# نگاهی به چند ردیف اول هر دیتافریم
print("---- df_divar ----")
print(df_divar.head())

print("---- df_city ----")
print(df_city.head())

# بررسی اطلاعات کلی
print(df_divar.info())
print(df_city.info())

# Rename columns in df_city for merging
df_city = df_city.rename(columns={'نام شهر': 'city_slug', 'دسته‌بندی': 'city_type'})

# ترکیب دیتافریم‌ها بر اساس ستون مشترک ('city_slug')
df = df_divar.merge(df_city[['city_slug', 'city_type']], on='city_slug', how='left')

# بررسی تعداد نمونه‌ها در هر گروه
print(df['city_type'].value_counts())
# Out:
# ---- df_divar ----
#    Unnamed: 0         cat2_slug       cat3_slug city_slug neighborhood_slug  \
# 0           0    temporary-rent           villa     karaj         mehrshahr
# 1           1  residential-sell  apartment-sell    tehran           gholhak
# 2           2  residential-rent  apartment-rent    tehran             tohid
# 3           3   commercial-rent     office-rent    tehran          elahiyeh
# 4           4  residential-sell  apartment-sell   mashhad          emamreza
#
#       created_at_month    user_type  \
# 0  2024-08-01 00:00:00  مشاور املاک
# 1  2024-05-01 00:00:00  مشاور املاک
# 2  2024-10-01 00:00:00          NaN
# 3  2024-06-01 00:00:00          NaN
# 4  2024-05-01 00:00:00  مشاور املاک
#
#                                          description  \
# 0  ۵۰۰متر\n۲۰۰متر بنا دوبلکس\n۳خواب\nاستخر آبگرم ...
# 1  دسترسی عالی به مترو و شریعتی \nمشاعات تمیز \nب...
# 2                                    تخلیه پایان ماه
# ...

# %%
print(df[['city_slug', 'city_type', 'building_size']].head())

# فقط داده‌های دارای building_size معتبر و city_type معتبر
df = df[df['building_size'].notnull() & df['city_type'].notnull()]

# تعداد نمونه‌ها در هر گروه
print(df['city_type'].value_counts())
# Out:
#   city_slug city_type  building_size
# 0     karaj  کلان‌شهر          500.0
# 1    tehran  کلان‌شهر           60.0
# 2    tehran  کلان‌شهر          132.0
# 3    tehran  کلان‌شهر           90.0
# 4   mashhad  کلان‌شهر          115.0
# city_type
# شهر کوچک    488988
# کلان‌شهر    455121
# Name: count, dtype: int64

# %%
import numpy as np
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# برای بررسی نرمال بودن روی چند نمونه 1000تایی
def check_normality(data, group_name, n_samples=5, sample_size=1000):
    shapiro_results = []
    for i in range(n_samples):
        sample = data.sample(sample_size, random_state=i)
        stat, p = shapiro(sample)
        shapiro_results.append((stat, p))
        print(f"{group_name} sample {i+1}: W={stat:.4f}, p={p:.4f}")
    return shapiro_results

# جدا کردن داده‌ها بر اساس نوع شهر
building_city = df[df['city_type']=='کلان‌شهر']['building_size']
building_small = df[df['city_type']=='شهر کوچک']['building_size']

# رسم توزیع و چولگی
for data, name in zip([building_city, building_small], ['Metropolis', 'Small City']):
    plt.figure(figsize=(8,4))
    sns.histplot(data, kde=True, bins=50)
    plt.title(f"Distribution of building_size for {name}")
    plt.show()
    print(f"{name} skewness: {data.skew():.4f}")

# اجرای Shapiro
shapiro_city = check_normality(building_city, 'کلان‌شهر')
shapiro_small = check_normality(building_small, 'شهر کوچک')
# Out:
# Metropolis skewness: 79.0116
# Small City skewness: 49.6395
# کلان‌شهر sample 1: W=0.0544, p=0.0000
# کلان‌شهر sample 2: W=0.0166, p=0.0000
# کلان‌شهر sample 3: W=0.0142, p=0.0000
# کلان‌شهر sample 4: W=0.0365, p=0.0000
# کلان‌شهر sample 5: W=0.0347, p=0.0000
# شهر کوچک sample 1: W=0.0304, p=0.0000
# شهر کوچک sample 2: W=0.0551, p=0.0000
# شهر کوچک sample 3: W=0.0397, p=0.0000
# شهر کوچک sample 4: W=0.0161, p=0.0000
# شهر کوچک sample 5: W=0.0316, p=0.0000

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

# جدا کردن گروه‌ها
groups = {'Metropolis': building_city, 'Small City': building_small}

for name, data in groups.items():
    plt.figure(figsize=(6,6))
    stats.probplot(data.sample(1000, random_state=0), dist="norm", plot=plt)
    plt.title(f"Q-Q plot of building_size for {name}")
    plt.show()

# %%
from sklearn.preprocessing import PowerTransformer
import pandas as pd

# ساخت دیتافریم برای نرمال‌سازی
data = df[['building_size', 'city_type']].copy()


pt = PowerTransformer(method='yeo-johnson')
data['building_size_transformed'] = pt.fit_transform(data['building_size'].values.reshape(-1,1))

# %%
city_trans = data[data['city_type']=='کلان‌شهر']['building_size_transformed']
small_trans = data[data['city_type']=='شهر کوچک']['building_size_transformed']

import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro

# رسم هیستوگرام بعد از نرمال‌سازی
for group, name in zip([city_trans, small_trans], ['Metropolis', 'Small City']):
    plt.figure(figsize=(8,4))
    sns.histplot(group.sample(1000, random_state=0), kde=True, bins=50)
    plt.title(f"Distribution of building_size (transformed) for {name}")
    plt.show()

    # روی نمونه 1000 تایی
    stat, p = shapiro(group.sample(1000, random_state=0))
    print(f"{name} after transformation: W={stat:.4f}, p={p:.4f}")
# Out:
# Metropolis after transformation: W=0.9157, p=0.0000
# Small City after transformation: W=0.8700, p=0.0000
