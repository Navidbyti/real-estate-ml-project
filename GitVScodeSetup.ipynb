# %% [markdown]
# <div dir="rtl" align="right">
#
# # راهنمای کامل راه‌اندازی Git و VS Code برای پروژه گروهی
#
# > این نوت‌بوک فقط شامل **سلول‌های Markdown** است و برای آموزش استفاده از Git، GitHub و VS Code در پروژه‌ی گروهی نوشته شده است.
#
# ---
#
# ##  هدف این راهنما
#
# بعد از خواندن این فایل، هر عضو تیم می‌تواند:
#
# * Git را روی سیستم خود نصب کند
# * Git را در VS Code راه‌اندازی کند
# * به GitHub لاگین کند
# * ریپازیتوری پروژه را clone کند
# * برنچ بسازد، commit بزند و push کند
#
# ---
#
# ## 1️⃣ نصب Git روی سیستم
#
# ### 🔹 ویندوز
#
# 1. به سایت رسمی Git بروید:
#    [https://git-scm.com](https://git-scm.com)
# 2. روی **Download for Windows** کلیک کنید
# 3. فایل را نصب کنید (همه گزینه‌ها Default باشد)
#
# ### 🔹 بررسی نصب
#
# CMD یا PowerShell را باز کنید و بزنید:
#
# ```bash
# git --version
# ```
#
# اگر نسخه نمایش داده شد، Git نصب است ✅
#
# ---
#
# ## 2️⃣ نصب VS Code
#
# 1. [https://code.visualstudio.com](https://code.visualstudio.com)
# 2. دانلود و نصب
# 3. اجرای VS Code
#
# ### افزونه‌های پیشنهادی
#
# * Python
# * Jupyter
# * GitLens (اختیاری ولی مفید)
#
# ---
#
# ## 3️⃣ تنظیم اولیه Git (فقط یک بار)
#
# در CMD / PowerShell / Terminal VS Code:
#
# ```bash
# git config --global user.name "Your Name"
# git config --global user.email "youremail@example.com"
# ```
#
# بررسی:
#
# ```bash
# git config --global --list
# ```
#
# ⚠️ ایمیل باید همان ایمیلی باشد که در GitHub استفاده کرده‌اید.
#
# ---
#
# ## 4️⃣ ساخت اکانت GitHub و لاگین
#
# 1. [https://github.com](https://github.com)
# 2. Sign up (اگر ندارید)
#
# ### 🔐 لاگین از طریق VS Code (پیشنهادی)
#
# * VS Code را باز کنید
# * Ctrl + Shift + P
# * بنویسید: `GitHub: Sign in`
# * لاگین در مرورگر انجام می‌شود
#
# VS Code به صورت خودکار GitHub را به Git متصل می‌کند ✅
#
# ---
#
# ## 5️⃣ Clone کردن پروژه
#
# در VS Code:
#
# 1. Ctrl + Shift + P
# 2. بنویسید: `Git: Clone`
# 3. لینک ریپو را وارد کنید:
#
# ```
# https://github.com/USERNAME/real-estate-ml-project.git
# ```
#
# 4. انتخاب محل ذخیره
# 5. Open Repository
#
# یا از ترمینال:
#
# ```bash
# git clone https://github.com/USERNAME/real-estate-ml-project.git
# cd real-estate-ml-project
# ```
#
# ---
#
# ## 6️⃣ ساخت برنچ شخصی
#
# ⚠️ هرگز روی main کار نکنید
#
# ```bash
# git checkout main
# git pull
# git checkout -b navid-questions
# ```
#
# بررسی:
#
# ```bash
# git branch
# ```
#
# برنچ فعال با `*` مشخص می‌شود.
#
# ---
#
# ## 7️⃣ روند استاندارد کار روزانه
#
# ### 🔹 1. Pull قبل از شروع
#
# ```bash
# git pull
# ```
#
# ### 🔹 2. فقط روی فایل شخصی خودت کار کن
#
# مثال:
#
# ```
# 1-Questions/drafts/navid-questions.ipynb
# ```
#
# ### 🔹 3. Commit
#
# ```bash
# git add 1-Questions/drafts/navid-questions.ipynb
# git commit -m "تحلیل سوالات اختصاص داده شده"
# ```
#
# ### 🔹 4. Push
#
# ```bash
# git push origin navid-questions
# ```
#
# ---
#
# ## 8️⃣ Pull Request (PR) چیست و کجا انجام می‌شود؟
#
# Pull Request یعنی درخواست ادغام کد شما با main.
#
# ### مراحل:
#
# 1. رفتن به GitHub
# 2. مشاهده پیام "Compare & Pull Request"
# 3. نوشتن توضیح کوتاه
# 4. Open Pull Request
# 5. بعد از تأیید → Merge
#
# ❌ بدون PR هیچ چیزی وارد main نمی‌شود.
#
# ---
#
# ## 9️⃣ دستورات مهم Git (خلاصه)
#
# | دستور                 | توضیح           |
# | --------------------- | --------------- |
# | git status            | وضعیت فایل‌ها   |
# | git branch            | لیست برنچ‌ها    |
# | git checkout <branch> | تغییر برنچ      |
# | git pull              | دریافت تغییرات  |
# | git add .             | افزودن فایل‌ها  |
# | git commit -m         | ثبت تغییر       |
# | git push              | ارسال به GitHub |
#
# ---
#
# ## ⚠️ قوانین طلایی تیم
#
# * ❌ کامیت مستقیم روی main ممنوع
# * ❌ ویرایش نوت‌بوک دیگران ممنوع
# * ✅ همیشه قبل از کار git pull
# * ✅ هر بخش = برنچ جدا
#
# ---
#
#
# اگر همه این مراحل را انجام دهند:
#
# * پروژه بدون conflict جلو می‌رود
# * نوت‌بوک‌ها سالم می‌مانند
# * تحویل نهایی حرفه‌ای خواهد بود
#
# موفق باشید 🚀
# </div>
